# %%
x=5
print(x)
# Out:
# 5

# %%
'''
hbhgbubjnn
'''
# Out:
# '\nhbhgbubjnn\n'

# %%
''''''
# Out:
# ''

# %%
print("bishoy " \
"")
name
# Out:
# bishoy

# %%
name "bishoy"
# Out:
#   Cell In[6], line 1
#     name "bishoy"
#          ^
# SyntaxError: invalid syntax

# %%
name = "bishoy"
age =30
print("my name is ",name)
# Out:
# my name is  bishoy

# %%
name = "bishoy"
age =27
print("my name {} and my age {}".format(name, age))
# Out:
# my name bishoy and my age 27

# %%
name ="bishoyyy"
age = 28
Course = "AI"
print(f"my name is {name} and my age is {age} study COURSE {Course}")
# Out:
# my name is bishoyyy and my age is 28 study COURSE AI

# %%
na="bis"
na.capitalize()
# Out:
# 'Bis'
